# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Load the datasets
dataset_train = pd.read_csv('PM_train.txt', sep=' ', header=None).drop([26, 27], axis=1)
col_names = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
dataset_train.columns = col_names
print('Shape of Train dataset: ', dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Train dataset:  (20631, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0
#
#      s20      s21
# 0  39.06  23.4190
# 1  39.00  23.4236
# 2  38.95  23.3442
# 3  38.88  23.3739
# 4  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
dataset_test = pd.read_csv('PM_test.txt', sep=' ', header=None).drop([26, 27], axis=1)
dataset_test.columns = col_names
print('Shape of Test dataset: ', dataset_train.shape)
dataset_train.head()
# Out:
# Shape of Test dataset:  (20631, 26)
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0
# 1  14.62  ...  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0
# 2  14.62  ...  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0
# 3  14.62  ...  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0
# 4  14.62  ...  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0
#
#      s20      s21
# 0  39.06  23.4190
# 1  39.00  23.4236
# 2  38.95  23.3442
# 3  38.88  23.3739
# 4  38.90  23.4044
#
# [5 rows x 26 columns]

# %%
pm_truth = pd.read_csv('Truth Value.txt', sep=' ', header=None).drop([1], axis=1)
pm_truth.columns = ['more']
pm_truth['id'] = pm_truth.index + 1
pm_truth.head()
# Out:
#    more  id
# 0    93   1
# 1    91   2
# 2    95   3
# 3   111   4
# 4    96   5

# %%
rul = pd.DataFrame(dataset_test.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
rul.head()
# Out:
#    id  max
# 0   1   31
# 1   2   49
# 2   3  126
# 3   4  106
# 4   5   98

# %%
pm_truth['rtf'] = pm_truth['more'] + rul['max']
pm_truth.head()
# Out:
#    more  id    rtf
# 0    93   1  124.0
# 1    91   2  140.0
# 2    95   3  221.0
# 3   111   4  217.0
# 4    96   5  194.0

# %%
pm_truth.drop('more', axis=1, inplace=True)
dataset_test = dataset_test.merge(pm_truth, on=['id'], how='left')
dataset_test['ttf'] = dataset_test['rtf'] - dataset_test['cycle']
dataset_test.drop('rtf', axis=1, inplace=True)
dataset_test.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1    0.0023    0.0003     100.0  518.67  643.02  1585.29  1398.21
# 1   1      2   -0.0027   -0.0003     100.0  518.67  641.71  1588.45  1395.42
# 2   1      3    0.0003    0.0001     100.0  518.67  642.46  1586.94  1401.34
# 3   1      4    0.0042    0.0000     100.0  518.67  642.44  1584.12  1406.42
# 4   1      5    0.0014    0.0000     100.0  518.67  642.51  1587.19  1401.92
#
#       s5  ...      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  14.62  ...  2388.03  8125.55  8.4052  0.03  392  2388  100.0  38.86
# 1  14.62  ...  2388.06  8139.62  8.3803  0.03  393  2388  100.0  39.02
# 2  14.62  ...  2388.03  8130.10  8.4441  0.03  393  2388  100.0  39.08
# 3  14.62  ...  2388.05  8132.90  8.3917  0.03  391  2388  100.0  39.00
# 4  14.62  ...  2388.03  8129.54  8.4031  0.03  390  2388  100.0  38.99
#
#        s21    ttf
# 0  23.3735  123.0
# 1  23.3916  122.0
# 2  23.4166  121.0
# 3  23.3737  120.0
# 4  23.4130  119.0
#
# [5 rows x 27 columns]

# %%
dataset_train['ttf'] = dataset_train.groupby(['id'])['cycle'].transform(max) - dataset_train['cycle']
dataset_train.head()
# Out:
# C:\Users\upaul.ext\AppData\Local\Temp\ipykernel_7224\1610690265.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   dataset_train['ttf'] = dataset_train.groupby(['id'])['cycle'].transform(max) - dataset_train['cycle']
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18    s19    s20  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90
#
#        s21  ttf
# 0  23.4190  191
# 1  23.4236  190
# 2  23.3442  189
# 3  23.3739  188
# 4  23.4044  187
#
# [5 rows x 27 columns]

# %%
df_train = dataset_train.copy()
df_test = dataset_test.copy()

# %%
features_col_name = ['setting1', 'setting2', 'setting3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11',
                     's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
target_col_name = 'ttf'

# %%
sc = MinMaxScaler()
df_train[features_col_name] = sc.fit_transform(df_train[features_col_name])
df_test[features_col_name] = sc.transform(df_test[features_col_name])

# %%
X_train = df_train[features_col_name]
y_train = df_train[target_col_name]
X_test = df_test[features_col_name]
y_test = df_test[target_col_name]

# %%
# Create linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict and evaluate the model
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
print("Train set evaluation:")
print('Mean Squared Error:', mean_squared_error(y_train, y_pred_train))
print('R-squared:', r2_score(y_train, y_pred_train))
# Out:
# Train set evaluation:
# Mean Squared Error: 1994.547737619331
# R-squared: 0.5795961126406292

# %%
# If y_test and y_pred_test are pandas Series
if isinstance(y_test, pd.Series):
    print("NaN values in y_test:", y_test.isna().sum())
    y_test = y_test.fillna(y_test.mean())
    y_test = y_test.reset_index(drop=True)
# Out:
# NaN values in y_test: 647

# %%
# If y_test and y_pred_test are numpy arrays
if isinstance(y_test, np.ndarray):
    print("NaN values in y_test:", np.isnan(y_test).sum())
    y_test = np.where(np.isnan(y_test), np.nanmean(y_test), y_test)

# %%
# If y_pred_test is pandas Series
if isinstance(y_pred_test, pd.Series):
    print("NaN values in y_pred_test:", y_pred_test.isna().sum())
    y_pred_test = y_pred_test.fillna(y_pred_test.mean())
    y_pred_test = y_pred_test.reset_index(drop=True)

# %%
# If y_pred_test is numpy arrays
if isinstance(y_pred_test, np.ndarray):
    print("NaN values in y_pred_test:", np.isnan(y_pred_test).sum())
    y_pred_test = np.where(np.isnan(y_pred_test), np.nanmean(y_pred_test), y_pred_test)
# Out:
# NaN values in y_pred_test: 0

# %%
# Ensure both are numpy arrays
if not isinstance(y_test, np.ndarray):
    y_test = y_test.to_numpy()

# %%
if not isinstance(y_pred_test, np.ndarray):
    y_pred_test = y_pred_test.to_numpy()

# %%
# Ensure that the lengths of y_test and y_pred_test match
if len(y_test) != len(y_pred_test):
    min_len = min(len(y_test), len(y_pred_test))
    y_test = y_test[:min_len]
    y_pred_test = y_pred_test[:min_len]

# %%
# Calculate and print the metrics
print("\nTest set evaluation:")
print('Mean Squared Error:', mean_squared_error(y_test, y_pred_test))
print('R-squared:', r2_score(y_test, y_pred_test))
# Out:
# Test set evaluation:
# Mean Squared Error: 4625.645675545877
# R-squared: 0.004406514052377575

# %%
def prob_failure(machine_id):
    machine_df = df_test[df_test.id == machine_id]
    machine_test = machine_df[features_col_name]
    m_pred = model.predict(machine_test)
    last_prediction = m_pred[-1]

# %%
last_prediction = y_pred_test[-1] if len(y_pred_test) > 0 else None

# %%
# Calculate the probability of failure within 30 days
if last_prediction is not None:
    if last_prediction <= 30:
        failure_prob = 1.0
    else:
        failure_prob = 0.0
    print("Probability of failure within 30 days:", failure_prob)
else:
    print("No predictions available to calculate failure probability.")
# Out:
# Probability of failure within 30 days: 1.0

# %%
#y_pred_test = np.array([50, 45, 40, 35, 20, 25, 15, 10])

# %%
# Set the desired threshold
threshold_days = 3

# %%
# Ensure there are predictions available
if len(y_pred_test) > 0:
    # Define last_prediction
    last_prediction = y_pred_test[-1]

# %%
 # Calculate the probability of failure within the threshold_days
if last_prediction <= threshold_days:
        failure_prob = 1.0
else:
        failure_prob = 0.0

print(f"Probability of failure within {threshold_days} days:", failure_prob)
# Out:
# Probability of failure within 3 days: 1.0

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (1.32.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\upaul.ext\appdata\roaming\python\python312\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\upaul.ext\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\upaul.ext\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\upaul.ext\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\upaul.ext\appdata\local\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\upaul.ext\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
